# %% [markdown]
# <a href="https://colab.research.google.com/github/Sana-Allah-Kheiri/Image_Processing_with_SciKit_Image_Lib/blob/main/Displaying_Gray_Rocket_Image_using_Customized_Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from skimage import data
from skimage import color
from matplotlib import pyplot as plt

def show_image (image, topic, cmap_type, axisMode):
    plt.imshow(image, cmap = cmap_type)
    plt.title(topic)
    plt.axis(axisMode)
    plt.show()


rocketImg = data.rocket()
grayRocket = color.rgb2gray(rocketImg)
OriginalRocket = color.gray2rgb(grayRocket)
#print('\n Gray-Scaled Channel\n' ,grayRocket, '\n RGB channel')
#print(OriginalRocket)
#print('There is a first time for everything! Congrats Sir for your 1st step!!')
show_image(OriginalRocket, "Gray-Scaled Rocket Image", 'gray','on')
